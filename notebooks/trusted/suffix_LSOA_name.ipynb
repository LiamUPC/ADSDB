# %%
# %%capture
# !pip install duckdb
# !pip install ipython-sql
# !pip install SQLAlchemy
# !pip install duckdb-engine

# %% [markdown]
# #Drive mount

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #Import & setup

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlalchemy
from datetime import datetime as dt
import glob

# Import ipython-sql Jupyter extension to create SQL cells
# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: Config option `displaycon` not recognized by `SqlMagic`.  Did you mean `displaylimit`?
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# %sql duckdb:////content/drive/MyDrive/ADSDBProject/formatted/crimesPrices.db
# to use a database file (shared between processes)
mostRecent = glob.glob("/content/drive/MyDrive/ADSDB/ADSDB Project/trusted/*.db")[-1]
con = duckdb.connect(database=mostRecent)

# %%
crimes = con.execute("SELECT * FROM crimes").df()
prices = con.execute("SELECT * FROM prices").df()

# %%
crimes['LSOA name']
# Out:
# 0        Bassetlaw 015F
# 1           Boston 001A
# 2           Boston 001A
# 3           Boston 001A
# 4           Boston 001A
#               ...
# 78999      Lincoln 006B
# 79000      Lincoln 006B
# 79001      Lincoln 006B
# 79002      Lincoln 006B
# 79003      Lincoln 006B
# Name: LSOA name, Length: 79004, dtype: object

# %%
crimes['LSOA name'].unique()

# %%
crimes
# Out:
#                                                 Crime ID    Month  \
# 0                                                    NaN  2020-06
# 1                                                    NaN  2020-06
# 2                                                    NaN  2020-06
# 3                                                    NaN  2020-06
# 4                                                    NaN  2020-06
# ...                                                  ...      ...
# 78999                                                NaN  2021-02
# 79000                                                NaN  2021-02
# 79001                                                NaN  2021-02
# 79002  4c7c59ac8f79034a6cb6abd3612aafd85e2a0e058b2113...  2021-02
# 79003  9b36fe02ff1aa4f986c6fc38302ee20139e44378812b1f...  2021-02
#
#                Reported by         Falls within  Longitude   Latitude  \
# 0      Lincolnshire Police  Lincolnshire Police  -0.775772  53.266281
# 1      Lincolnshire Police  Lincolnshire Police   0.065595  52.983426
# 2      Lincolnshire Police  Lincolnshire Police   0.065595  52.983426
# 3      Lincolnshire Police  Lincolnshire Police   0.065595  52.983426
# 4      Lincolnshire Police  Lincolnshire Police   0.065595  52.983426
# ...                    ...                  ...        ...        ...
# 78999  Lincolnshire Police  Lincolnshire Police  -0.538147  53.223655
# 79000  Lincolnshire Police  Lincolnshire Police  -0.540080  53.226735
# 79001  Lincolnshire Police  Lincolnshire Police  -0.539346  53.223642
# 79002  Lincolnshire Police  Lincolnshire Police  -0.531439  53.222260
# 79003  Lincolnshire Police  Lincolnshire Police  -0.541377  53.222939
#
#                           Location  LSOA code  LSOA name  \
# 0            On or near Marsh Lane  E01028039  Bassetlaw
# 1           On or near Church Road  E01026007     Boston
# 2           On or near Church Road  E01026007     Boston
# 3           On or near Church Road  E01026007     Boston
# 4           On or near Church Road  E01026007     Boston
# ...                            ...        ...        ...
# 78999      On or near Lewis Street  E01026176    Lincoln
# 79000  On or near St Mary'S Street  E01026176    Lincoln
# 79001   On or near Portland Street  E01026176    Lincoln
# 79002      On or near Elliott Road  E01026176    Lincoln
# 79003     On or near Hermit Street  E01026176    Lincoln
#
#                       Crime type  \
# 0          Anti-social behaviour
# 1          Anti-social behaviour
# 2          Anti-social behaviour
# 3          Anti-social behaviour
# 4          Anti-social behaviour
# ...                          ...
# 78999      Anti-social behaviour
# 79000      Anti-social behaviour
# 79001      Anti-social behaviour
# 79002              Bicycle theft
# 79003  Criminal damage and arson
#
#                                Last outcome category  Context
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
# ...                                              ...      ...
# 78999                                            NaN      NaN
# 79000                                            NaN      NaN
# 79001                                            NaN      NaN
# 79002  Investigation complete; no suspect identified      NaN
# 79003                       Court result unavailable      NaN
#
# [79004 rows x 12 columns]

# %%
crimes['LSOA name'].unique()
# Out:
# array(['Bassetlaw', 'Boston', 'East Lindsey', 'Fenland', 'Lincoln',
#        'Newark and Sherwood', 'North East Lincolnshire', 'North Kesteven',
#        'Rutland', 'South Holland', 'South Kesteven', 'Peterborough',
#        'West Lindsey', 'Cheshire East', 'Craven', nan,
#        "King's Lynn and West Norfolk", 'North Lincolnshire',
#        'North Norfolk', 'Scarborough', 'Melton'], dtype=object)
