# %%
# %%capture
# !pip install duckdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 16.4 MB 3.5 MB/s
# ...

# %% [markdown]
# <h2>Imports & Setup</h2>

# %%
import duckdb
import pandas as pd
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: UserWarning: Config option `displaycon` not recognized by `SqlMagic`.  Did you mean `displaylimit`?
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
con = duckdb.connect(database="../../data/formatted/crimesPrices.db")
# Out:
# (duckdb.IOException) IO Error: Cannot open file "/content/drive/MyDrive/ADSDBProject/formatted/crimesPrices.db": No such file or directory
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# <h2>Crimes Table</h2>

# %%
# -- read_csv with custom options
con.execute("CREATE TABLE crimes AS SELECT * FROM read_csv_auto('../../data/landing/persistent/crimes/*.csv');")
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
con.execute("SELECT * FROM crimes;")
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %sql DROP TABLE crimes
# %sql DROP TABLE prices
# Out:
#  * duckdb:////content/drive/MyDrive/ADSDBProject/formatted/crimesPrices.db
#  * duckdb:////content/drive/MyDrive/ADSDBProject/formatted/crimesPrices.db
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# <h2>Prices Table</h2>

# %%
# -- read_csv with custom options
con.execute("CREATE TABLE prices AS SELECT * FROM read_csv_auto('../../data/landing/persistent/prices/*.csv');")
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
con.execute("SELECT * FROM crimes;")
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
